# %% [markdown]
# # How to generate a combined utility/privacy report?

# %% [markdown]
# ### Create a combined report of the metrics, whether they are utility or privacy metrics. /!\ Only for the summary.

# %% [markdown]
# Assume that the synthetic data is already generated \
# Based on the Wisconsin Breast Cancer Dataset (WBCD)

# %%
# Standard library
import sys
import tempfile

sys.path.append("..")

# 3rd party packages
import pandas as pd

# Local packages
import config
import utils.draw
from metrics.report import Report

# %% [markdown]
# ## Load the real and synthetic Wisconsin Breast Cancer Datasets

# %%
df_real = {}
df_real["train"] = pd.read_csv("../data/WBCD_train.csv")
df_real["test"] = pd.read_csv("../data/WBCD_test.csv")
df_real["train"].shape
# Out:
# (455, 10)

# %% [markdown]
# ### Choose the synthetic dataset

# %%
df_synth = {}
df_synth["train"] = pd.read_csv("../results/data/2024-02-15_Synthpop_455samples.csv")
df_synth["test"] = pd.read_csv("../results/data/2024-02-15_Synthpop_228samples.csv")
df_synth["2nd_gen"] = pd.read_csv(
    "../results/data/2024-02-15_Synthpop_455samples_2nd_gen.csv"
)
df_synth["test"].shape
# Out:
# (228, 10)

# %% [markdown]
# ## Configure the metadata dictionary

# %% [markdown]
# ### The continuous and categorical variables need to be specified, as well as the variable to predict

# %%
metadata = {
    "continuous": [
        "Clump_Thickness",
        "Uniformity_of_Cell_Size",
        "Uniformity_of_Cell_Shape",
        "Marginal_Adhesion",
        "Single_Epithelial_Cell_Size",
        "Bland_Chromatin",
        "Normal_Nucleoli",
        "Mitoses",
        "Bare_Nuclei",
    ],
    "categorical": ["Class"],
    "variable_to_predict": "Class",
}

# %% [markdown]
# ## Generate the report

# %%
parameters = {  # see the notebooks utility_report and privacy_report for more details
    "cross_learning": False,
    "num_repeat": 1,
    "num_kfolds": 3,
    "num_optuna_trials": 15,
    "use_gpu": True,
    "sampling_frac": 0.5,
}

# %%
report = Report(
    dataset_name="Wisconsin Breast Cancer Dataset",
    df_real=df_real,
    df_synthetic=df_synth,
    metadata=metadata,
    figsize=(8, 6),  # will be automatically adjusted for larger or longer figures
    random_state=42,  # for reproducibility purposes
    report_folderpath=None,  # load computed utility and/or privacy reports if available
    report_filename=None,  # the name of the computed report (without extension nor utility/privacy) if available
    metrics=None,  # list of the metrics to compute. Can be utility or privacy metrics. If not specified, all the metrics are computed.
    params=parameters,  # the dictionary containing the parameters for both utility and privacy reports
)

# %%
report.compute()
# Out:
# LOGAN test set shape: (228, 10)
# TableGan test set shape: (228, 10)
# Detector test set shape: (228, 10)

# %% [markdown]
# ## Get the summary report as a pandas dataframe

# %%
report.specification()
# Out:
# ----- Wisconsin Breast Cancer Dataset -----
# Contains:
#     - 455 instances in the train set,
#     - 228 instances in the test set,
#     - 10 variables, 9 continuous and 1 categorical.

# %%
df_summary = report.summary()

# %%
by = ["name", "objective", "min", "max"]
df_summary.groupby(by).apply(lambda x: x.drop(by, axis=1).reset_index(drop=True))
# Out:
#                                                                                    alias  \
# name                                          objective min max
# Categorical Consistency                       max       0   1.0 0             cat_consis
# Categorical Statistics                        max       0   1.0 0              cat_stats
#                                                                 1              cat_stats
# Classification                                min       0   1.0 0                classif
# Collision                                     max       0   1.0 0              collision
#                                                                 1              collision
#                                                                 2              collision
#                                                                 3              collision
#                                                             inf 0              collision
#                                                                 1              collision
#                                                                 2              collision
#                                                                 3              collision
#                                                                 4              collision
# Continuous Consistency                        max       0   1.0 0            cont_consis
# Continuous Statistics                         min       0   inf 0             cont_stats
#                                                                 1             cont_stats
# DCR                                           max       0   1.0 0                    dcr
#                                                                 1                    dcr
#                                                             inf 0                    dcr
#                                                                 1                    dcr
#                                               min       0   1.0 0                    dcr
#                                                                 1                    dcr
# Detector                                      max       0   1.0 0               detector
#                                                                 1               detector
#                                                                 2               detector
#                                                                 3               detector
#                                                                 4               detector
# Distinguishability                            min       0   1.0 0                   dist
#                                                                 1                   dist
#                                                                 2                   dist
#                                                                 3                   dist
# FScore                                        min       0   inf 0                 fscore
# Feature Importance                            min       0   inf 0            feature_imp
# GAN-Leaks                                     max       0   1.0 0               ganleaks
#                                                                 1               ganleaks
# Hellinger Categorical Univariate Distance     min       0   1.0 0     hell_cat_univ_dist
# Hellinger Continuous Univariate Distance      min       0   1.0 0    hell_cont_univ_dist
# KL Divergence Categorical Univariate Distance min       0   inf 0   kl_div_cat_univ_dist
# KL Divergence Continuous Univariate Distance  min       0   inf 0  kl_div_cont_univ_dist
# LOGAN                                         max       0   1.0 0                  logan
#                                                                 1                  logan
#                                                                 2                  logan
#                                                                 3                  logan
#                                                                 4                  logan
# Monte Carlo Membership                        max       0   1.0 0            mcmebership
#                                                                 1            mcmebership
# Pairwise Correlation Difference               min       0   inf 0                    pcd
# TableGan                                      max       0   1.0 0               tablegan
#                                                                 1               tablegan
#                                                                 2               tablegan
#                                                                 3               tablegan
#                                                                 4               tablegan
#
#                                                                                             submetric  \
# name                                          objective min max
# Categorical Consistency                       max       0   1.0 0                        within_ratio
# Categorical Statistics                        max       0   1.0 0                    support_coverage
#                                                                 1                  frequency_coverage
# Classification                                min       0   1.0 0                     diff_real_synth
# Collision                                     max       0   1.0 0                           precision
#                                                                 1                              recall
#                                                                 2                            f1_score
#                                                                 3                       recovery_rate
#                                                             inf 0        avg_num_appearance_realtrain
#                                                                 1      avg_num_appearance_realcontrol
#                                                                 2            avg_num_appearance_synth
#                                                                 3   avg_num_appearance_collision_real
#                                                                 4  avg_num_appearance_collision_synth
# Continuous Consistency                        max       0   1.0 0                        within_ratio
# Continuous Statistics                         min       0   inf 0                  median_l1_distance
#                                                                 1                     iqr_l1_distance
# DCR                                           max       0   1.0 0    nndr_5th_percent_synthreal_train
#                                                                 1  nndr_5th_percent_synthreal_control
#                                                             inf 0     dcr_5th_percent_synthreal_train
#                                                                 1   dcr_5th_percent_synthreal_control
#                                               min       0   1.0 0         ratio_match_synthreal_train
#                                                                 1       ratio_match_synthreal_control
# Detector                                      max       0   1.0 0                     precision_top1%
#                                                                 1                    precision_top50%
#                                                                 2                           precision
#                                                                 3                   tpr_at_0.001%_fpr
#                                                                 4                     tpr_at_0.1%_fpr
# Distinguishability                            min       0   1.0 0                      prediction_mse
#                                                                 1                 prediction_mse_real
#                                                                 2                prediction_mse_synth
#                                                                 3             prediction_auc_rescaled
# FScore                                        min       0   inf 0                        diff_f_score
# Feature Importance                            min       0   inf 0         diff_permutation_importance
# GAN-Leaks                                     max       0   1.0 0                     precision_top1%
#                                                                 1                    precision_top50%
# Hellinger Categorical Univariate Distance     min       0   1.0 0                  hellinger_distance
# Hellinger Continuous Univariate Distance      min       0   1.0 0                  hellinger_distance
# KL Divergence Categorical Univariate Distance min       0   inf 0                       kl_divergence
# KL Divergence Continuous Univariate Distance  min       0   inf 0                       kl_divergence
# LOGAN                                         max       0   1.0 0                     precision_top1%
#                                                                 1                    precision_top50%
#                                                                 2                           precision
#                                                                 3                   tpr_at_0.001%_fpr
#                                                                 4                     tpr_at_0.1%_fpr
# Monte Carlo Membership                        max       0   1.0 0                     precision_top1%
#                                                                 1                    precision_top50%
# Pairwise Correlation Difference               min       0   inf 0                                norm
# TableGan                                      max       0   1.0 0                     precision_top1%
#                                                                 1                    precision_top50%
#                                                                 2                           precision
#                                                                 3                   tpr_at_0.001%_fpr
#                                                                 4                     tpr_at_0.1%_fpr
#
#                                                                       value
# name                                          objective min max
# Categorical Consistency                       max       0   1.0 0  1.000000
# Categorical Statistics                        max       0   1.0 0  1.000000
#                                                                 1  0.975824
# Classification                                min       0   1.0 0  0.001478
# Collision                                     max       0   1.0 0  0.460317
#                                                                 1  0.966667
#                                                                 2  0.623656
#                                                                 3  0.186495
#                                                             inf 0  1.463023
#                                                                 1  1.349112
#                                                                 2  1.552901
#                                                                 3  3.250000
#                                                                 4  3.566667
# Continuous Consistency                        max       0   1.0 0  1.000000
# Continuous Statistics                         min       0   inf 0  0.000000
#                                                                 1  0.049383
# DCR                                           max       0   1.0 0  0.000000
#                                                                 1  0.000000
#                                                             inf 0  0.000000
#                                                                 1  0.000000
#                                               min       0   1.0 0  0.368421
#                                                                 1  0.377193
# Detector                                      max       0   1.0 0  1.000000
#                                                                 1  0.473684
#                                                                 2  0.478261
#                                                                 3  0.096491
#                                                                 4  0.096491
# Distinguishability                            min       0   1.0 0  0.025798
#                                                                 1  0.032699
#                                                                 2  0.018898
#                                                                 3  0.033568
# FScore                                        min       0   inf 0  0.353215
# Feature Importance                            min       0   inf 0  0.014686
# GAN-Leaks                                     max       0   1.0 0  0.000000
#                                                                 1  0.850877
# Hellinger Categorical Univariate Distance     min       0   1.0 0  0.018080
# Hellinger Continuous Univariate Distance      min       0   1.0 0  0.053864
# KL Divergence Categorical Univariate Distance min       0   inf 0  0.001300
# KL Divergence Continuous Univariate Distance  min       0   inf 0  0.012048
# LOGAN                                         max       0   1.0 0  1.000000
#                                                                 1  0.543860
#                                                                 2  0.551181
#                                                                 3  0.017544
#                                                                 4  0.017544
# Monte Carlo Membership                        max       0   1.0 0  0.500000
#                                                                 1  0.526316
# Pairwise Correlation Difference               min       0   inf 0  0.222504
# TableGan                                      max       0   1.0 0  0.500000
#                                                                 1  0.500000
#                                                                 2  0.513158
#                                                                 3  0.000000
#                                                                 4  0.000000

# %% [markdown]
# ## Save and load the report

# %%
with tempfile.TemporaryDirectory() as temp_dir:
    report.save(savepath=temp_dir, filename="report")  # save
    new_report = Report(report_folderpath=temp_dir, report_filename="report")  # load
